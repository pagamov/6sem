# %%
from data import * # settings
from lib import GCD,Q
from Primes import Primes
from Suive import suive

# %%
q = Q(n)
primes = Primes(n,B,q)
# Out:
# 25.24 %
# 51.21 %
# 76.41 %
# 99.99 %
# primes done in time: 0.7963 sec
# primes len 3953

# %%
# %timeit smooth_numbers = suive(q,primes)
# Out:
# MAX_SMOOTH_QTY: 3953
# found: 3955/3953 100.05 %
# MAX_SMOOTH_QTY: 3953
# found: 3956/3953 100.08 %
# MAX_SMOOTH_QTY: 3953
# found: 3956/3953 100.08 %
# MAX_SMOOTH_QTY: 3953
# found: 3956/3953 100.08 %
# MAX_SMOOTH_QTY: 3953
# found: 3956/3953 100.08 %
# MAX_SMOOTH_QTY: 3953
# found: 3955/3953 100.05 %
# MAX_SMOOTH_QTY: 3953
# found: 3956/3953 100.08 %
# MAX_SMOOTH_QTY: 3953
# found: 3956/3953 100.08 %
# 4min 48s ± 1 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# n = 10^40
# B = 80 * 10**3
# step = 100 * 10**3
